# %% [markdown]
# ## Importación de librerías y carga del modelo global

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from collections import OrderedDict
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import glob
import os
import sys

class PVModel(nn.Module):
    
    def __init__(self, layers_sizes=[256,128,64], input_size=3, dropout=0.1):
        super().__init__()
        
        layers = []
        
        for size in layers_sizes:
            layers.append(nn.Linear(input_size, size)) # Capa lineal
            layers.append(nn.BatchNorm1d(size)) # Batch Normalization
            layers.append(nn.ReLU()) # Activación
            layers.append(nn.Dropout(dropout)) # Dropout
            input_size = size # Actualiza para siguiente capa
        
        layers.append(nn.Linear(input_size, 1))
        
        self.model = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.model(x)

FEATURES = [
    "POA irradiance CMP22 pyranometer (W/m2)", "PV module back surface temperature (degC)",
    "Dry bulb temperature (degC)", "T_diff", "k_panel", "factor_panel", "physical_model",
    "poa_ghi_ratio", "dni_ghi_ratio", "dhi_ghi_ratio", "cloud_index", "temp_diff_air",
    "poa_temp", "ghi_temp"
]

# 1. Instanciar el modelo vacío
modelo = PVModel(input_size=len(FEATURES), layers_sizes=[256,128,64], dropout=0.1)

# 2. Cargar los pesos guardados por Docker
ruta_npz = "../federated-docker/modelos_guardados/modelo_global_final.npz"
pesos_numpy = np.load(ruta_npz)
lista_pesos = [pesos_numpy[arr] for arr in pesos_numpy.files]

# 3. Inyectar pesos en PyTorch
params_dict = zip(modelo.state_dict().keys(), lista_pesos)
state_dict = OrderedDict({k: torch.tensor(v) for k, v in params_dict})
modelo.load_state_dict(state_dict, strict=True)

print("Modelo Global Federado cargado correctamente.")
# Out:
# Modelo Global Federado cargado correctamente.

# %% [markdown]
# ## Preparación de Datos

# %%
# PARÁMETROS (Cambia "Golden" por el parque que quieras evaluar)
PARQUE = "Golden" 
DATA_PATH = "../PV_MaximumPowerPredictor" 

# Carga de datos
archivos = glob.glob(f"{DATA_PATH}/{PARQUE}_*.csv")
dfs = []
for archivo in archivos:
    df = pd.read_csv(archivo)
    df["panel_id"] = "_".join(os.path.basename(archivo).replace(".csv","").split("_")[1:])
    dfs.append(df)
df_parque = pd.concat(dfs, ignore_index=True)
df_parque = df_parque.drop(columns=["Time Stamp (local standard time) yyyy-mm-ddThh:mm:ss"], errors="ignore").replace(-9999, np.nan).dropna()

# Split cronológico (como en el cliente)
from sklearn.model_selection import train_test_split
train_val_df, test_df = train_test_split(df_parque, test_size=0.2, random_state=42)
train_df, _ = train_test_split(train_val_df, test_size=0.2, random_state=42)

# Constantes Físicas (Sólo Train)
k_por_panel, factor_por_panel = {}, {}
for pid, grupo in train_df.groupby("panel_id"):
    if len(grupo) >= 10:
        G = grupo["POA irradiance CMP22 pyranometer (W/m2)"].values
        T = grupo["PV module back surface temperature (degC)"].values
        P = grupo["Pmp (W)"].values
        y_k, X_k = P / (G + 1e-6), (T - 25).reshape(-1, 1)
        m = LinearRegression().fit(X_k, y_k)
        k_por_panel[pid] = float(-m.coef_[0])
        factor_por_panel[pid] = float(np.mean(P/ (G + 1e-6)))

k_global = np.mean(list(k_por_panel.values())) if k_por_panel else 0.004
factor_global = np.mean(list(factor_por_panel.values())) if factor_por_panel else 0.15

# ============================================================
# Feature Engineering aplicado a TRAIN y TEST
# ============================================================
for df in [train_df, test_df]:
    df["k_panel"] = df["panel_id"].map(k_por_panel).fillna(k_global)
    df["factor_panel"] = df["panel_id"].map(factor_por_panel).fillna(factor_global)
    
    df["physical_model"] = (
        df["POA irradiance CMP22 pyranometer (W/m2)"] * df["factor_panel"] * (1 - df["k_panel"] * (df["PV module back surface temperature (degC)"] - 25))
    )
    df["T_diff"] = df["PV module back surface temperature (degC)"] - 25
    df["poa_ghi_ratio"] = df["POA irradiance CMP22 pyranometer (W/m2)"] / (df["Global horizontal irradiance (W/m2)"] + 1e-6)
    df["dni_ghi_ratio"] = df["Direct normal irradiance (W/m2)"] / (df["Global horizontal irradiance (W/m2)"] + 1e-6)
    df["dhi_ghi_ratio"] = df["Diffuse horizontal irradiance (W/m2)"] / (df["Global horizontal irradiance (W/m2)"] + 1e-6)
    df["cloud_index"] = df["Diffuse horizontal irradiance (W/m2)"] / (df["Direct normal irradiance (W/m2)"] + 1e-6)
    df["temp_diff_air"] = df["PV module back surface temperature (degC)"] - df["Dry bulb temperature (degC)"]
    df["poa_temp"] = df["POA irradiance CMP22 pyranometer (W/m2)"] * df["PV module back surface temperature (degC)"]
    df["ghi_temp"] = df["Global horizontal irradiance (W/m2)"] * df["Dry bulb temperature (degC)"]

# Escalado
x_scaler, y_scaler = StandardScaler(), StandardScaler()
x_scaler.fit(train_df[FEATURES])
y_scaler.fit(train_df["Pmp (W)"].values.reshape(-1, 1))

X_test = x_scaler.transform(test_df[FEATURES])
y_test = y_scaler.transform(test_df["Pmp (W)"].values.reshape(-1, 1))

# Dataloader
from torch.utils.data import TensorDataset, DataLoader
test_loader = DataLoader(
    TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32)), 
    batch_size=256
)
print("Datos de Test procesados y listos.")
# Out:
# Datos de Test procesados y listos.

# %% [markdown]
# ## Incertidumbre y guardrail

# %%
def enable_dropout(m):
    if type(m) == nn.Dropout:
        m.train()

# 1. Habilitamos MC Dropout
modelo.eval()
modelo.apply(enable_dropout)

T = 30
test_preds_mc, test_targets, predicciones_fisicas = [], [], []

with torch.no_grad():
    for X, y in test_loader:
        # T pasadas estocásticas
        batch_preds = [modelo(X) for _ in range(T)]
        test_preds_mc.append(torch.stack(batch_preds))
        test_targets.append(y)
        
        # Extraer predicción física
        X_unscaled = x_scaler.inverse_transform(X.numpy())
        p_fisica = X_unscaled[:, 6] # Índice 6 es 'physical_model'
        predicciones_fisicas.extend(p_fisica)

# Transformaciones de dimensiones
test_preds_mc = torch.cat(test_preds_mc, dim=1).numpy()
test_targets = torch.cat(test_targets).numpy()
predicciones_fisicas = np.array(predicciones_fisicas).flatten()

T_shape, N_shape, _ = test_preds_mc.shape
test_preds_mc_unscaled = y_scaler.inverse_transform(test_preds_mc.reshape(-1, 1)).reshape(T_shape, N_shape)
test_targets_unscaled = y_scaler.inverse_transform(test_targets).flatten()

# CÁLCULO DE INCERTIDUMBRE
mean_preds = test_preds_mc_unscaled.mean(axis=0)
std_preds = test_preds_mc_unscaled.std(axis=0)

# CÁLCULO DE ERRORES REALES
errores_ia_pura = np.abs(test_targets_unscaled - mean_preds)
errores_fisica = np.abs(test_targets_unscaled - predicciones_fisicas)

# EL GUARDRAIL
UMBRAL = 8 # CAMBIAR Y PROBAR
test_preds_finales = np.where(std_preds > UMBRAL, predicciones_fisicas, mean_preds)

# METRICAS
mse_ia = ((test_targets_unscaled - mean_preds)**2).mean()
mse_guardrail = ((test_targets_unscaled - test_preds_finales)**2).mean()
mejora_pct = ((mse_ia - mse_guardrail) / mse_ia) * 100
correlacion = np.corrcoef(std_preds, errores_ia_pura)[0, 1]
activaciones = np.sum(std_preds > UMBRAL)

print(f"RESULTADOS DEL ANÁLISIS DE INCERTIDUMBRE (Umbral: {UMBRAL}W):")
print(f"Correlación Incertidumbre-Error : {correlacion:.4f} (Positiva indica que funciona bien)")
print(f"MSE IA sola                     : {mse_ia:.2f}")
print(f"MSE con Guardrail (Física)      : {mse_guardrail:.2f} (Mejora: {mejora_pct:.2f}%)")
print(f"Activaciones del Guardrail      : {activaciones} de {len(std_preds)} datos ({activaciones/len(std_preds)*100:.2f}%)")
# Out:
# 📊 RESULTADOS DEL ANÁLISIS DE INCERTIDUMBRE (Umbral: 8W):
# Correlación Incertidumbre-Error : 0.5952 (Positiva indica que funciona bien)
# MSE IA sola                     : 8.64
# MSE con Guardrail (Física)      : 8.37 (Mejora: 3.20%)
# Activaciones del Guardrail      : 517 de 19008 datos (2.72%)

# %% [markdown]
# ## Visualización

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Gráfica 1: Correlación Incertidumbre vs Error
axes[0].scatter(std_preds, errores_ia_pura, alpha=0.1, color='blue', s=10)
axes[0].axvline(x=UMBRAL, color='red', linestyle='--', label=f'Umbral Guardrail ({UMBRAL}W)')
axes[0].set_title("Incertidumbre vs Error Absoluto de la IA")
axes[0].set_xlabel("Incertidumbre Epistémica (Std. Dev.)")
axes[0].set_ylabel("Error Absoluto (W)")
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Añadir texto explicativo
axes[0].text(0.05, 0.95, f'Correlación Pearson: {correlacion:.2f}', 
             transform=axes[0].transAxes, fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

# Gráfica 2: Comparativa de MSE
nombres = ['IA Pura', 'Fórmula Física Pura', 'Sistema Híbrido (Guardrail)']
valores_mse = [mse_ia, (errores_fisica**2).mean(), mse_guardrail]
colores = ['#FF9999', '#99CCFF', '#99FF99']

barras = axes[1].bar(nombres, valores_mse, color=colores, edgecolor='black')
axes[1].set_title("Mejora del Error Cuadrático Medio (MSE)")
axes[1].set_ylabel("MSE")

# Añadir etiquetas de valor encima de las barras
for barra in barras:
    yval = barra.get_height()
    axes[1].text(barra.get_x() + barra.get_width()/2, yval + (yval*0.02), round(yval, 2), ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()
